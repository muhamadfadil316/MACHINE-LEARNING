# %% [markdown]
# <a href="https://colab.research.google.com/github/muhamadfadil316/MACHINE-LEARNING/blob/main/Praktikum13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
# Membaca file csv
df_titanic = pd.read_csv('titanic.csv')

df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Melihat nilai yang hilang
df_titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Drop Kolom
df_titanic = df_titanic.drop(columns=['Cabin', 'Name', 'Ticket'], axis=1)

# %%
# Visualisasi Distribusi dan Outlier pada Kolom Age
df_titanic.boxplot(column=['Age'])
# Out:
# <Axes: >

# %%
# Mengisi Nilai Kosong pada Kolom Age dengan Median
df_titanic['Age'].fillna(df_titanic['Age'].median(), inplace=True)
# Out:
# /tmp/ipython-input-518374384.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_titanic['Age'].fillna(df_titanic['Age'].median(), inplace=True)

# %%
# Mengisi Nilai Kosong pada Kolom Embarked dengan Modus
df_titanic['Embarked'].fillna(df_titanic['Embarked'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-3932522925.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_titanic['Embarked'].fillna(df_titanic['Embarked'].mode()[0], inplace=True)

# %%
df_titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
replacements = {
    'Sex': {'male': 0, 'female': 1},
    'Embarked': {'S': 0, 'C': 1, 'Q': 2}
}

df_titanic.replace(replacements, inplace=True)
# Out:
# /tmp/ipython-input-3773925907.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_titanic.replace(replacements, inplace=True)

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500         0
# 1            2         1       1    1  38.0      1      0  71.2833         1
# 2            3         1       3    1  26.0      0      0   7.9250         0
# 3            4         1       1    1  35.0      1      0  53.1000         0
# 4            5         0       3    0  35.0      0      0   8.0500         0

# %%
# split data variabel x dan y
X = df_titanic.drop(columns=['Survived'])
y = df_titanic['Survived']

# transform data
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
X_train.shape
# Out:
# (712, 8)

# %%
X_train.shape[1]
# Out:
# 8

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

model = Sequential()

# Hidden layer 1
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
# Dropout untuk mengurangi overfitting (Dropout to reduce overfitting)
model.add(Dropout(0.3))

# Hidden layer 2
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.3))

# Output layer (binary classification)
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 833 (3.25 KB)
#  Trainable params: 833 (3.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
# Training Model Neural Network
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5465 - loss: 0.7648 - val_accuracy: 0.6573 - val_loss: 0.6670
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6263 - loss: 0.6987 - val_accuracy: 0.6783 - val_loss: 0.6381
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6440 - loss: 0.6413 - val_accuracy: 0.6783 - val_loss: 0.6195
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6771 - loss: 0.6237 - val_accuracy: 0.6923 - val_loss: 0.6010
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6983 - loss: 0.6117 - val_accuracy: 0.7343 - val_loss: 0.5829
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6647 - loss: 0.6207 - val_accuracy: 0.7413 - val_loss: 0.5678
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6907 - loss: 0.6098 - val_accuracy: 0.7622 - val_loss: 0.5535
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7032 - loss: 0.5925 - val_accuracy: 0.7622 - val_loss: 0.5422
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7609 - loss: 0.5577 - val_accuracy: 0.7622 - val_loss: 0.5306
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7336 - loss: 0.5540 - val_accuracy: 0.7622 - val_loss: 0.5175
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7277 - loss: 0.5611 - val_accuracy: 0.7832 - val_loss: 0.5038
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7420 - loss: 0.5546 - val_accuracy: 0.7902 - val_loss: 0.4960
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7443 - loss: 0.5464 - val_accuracy: 0.8042 - val_loss: 0.4827
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7300 - loss: 0.5736 - val_accuracy: 0.8042 - val_loss: 0.4734
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7941 - loss: 0.4807 - val_accuracy: 0.8042 - val_loss: 0.4644
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7727 - loss: 0.5012 - val_accuracy: 0.8252 - val_loss: 0.4577
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8084 - loss: 0.4792 - val_accuracy: 0.8252 - val_loss: 0.4498
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7728 - loss: 0.5065 - val_accuracy: 0.8252 - val_loss: 0.4478
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7906 - loss: 0.4897 - val_accuracy: 0.8252 - val_loss: 0.4415
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7942 - loss: 0.4637 - val_accuracy: 0.8182 - val_loss: 0.4392
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7933 - loss: 0.5054 - val_accuracy: 0.8112 - val_loss: 0.4379
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7522 - loss: 0.4780 - val_accuracy: 0.8042 - val_loss: 0.4345
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8021 - loss: 0.5086 - val_accuracy: 0.8112 - val_loss: 0.4297
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8093 - loss: 0.4857 - val_accuracy: 0.8042 - val_loss: 0.4317
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7831 - loss: 0.5282 - val_accuracy: 0.8042 - val_loss: 0.4303
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8007 - loss: 0.4621 - val_accuracy: 0.8112 - val_loss: 0.4287
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8021 - loss: 0.4454 - val_accuracy: 0.8042 - val_loss: 0.4256
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8048 - loss: 0.4630 - val_accuracy: 0.8042 - val_loss: 0.4230
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8001 - loss: 0.4770 - val_accuracy: 0.8322 - val_loss: 0.4203
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8013 - loss: 0.4862 - val_accuracy: 0.8252 - val_loss: 0.4188
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7926 - loss: 0.4607 - val_accuracy: 0.8182 - val_loss: 0.4182
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8042 - loss: 0.4362 - val_accuracy: 0.8182 - val_loss: 0.4172
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7934 - loss: 0.4959 - val_accuracy: 0.8112 - val_loss: 0.4156
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8079 - loss: 0.4860 - val_accuracy: 0.8112 - val_loss: 0.4166
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8233 - loss: 0.4683 - val_accuracy: 0.8042 - val_loss: 0.4159
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8050 - loss: 0.4527 - val_accuracy: 0.8182 - val_loss: 0.4111
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7989 - loss: 0.4716 - val_accuracy: 0.8042 - val_loss: 0.4073
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7831 - loss: 0.4876 - val_accuracy: 0.8112 - val_loss: 0.4093
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7942 - loss: 0.4981 - val_accuracy: 0.8112 - val_loss: 0.4094
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7737 - loss: 0.4823 - val_accuracy: 0.8182 - val_loss: 0.4074
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8088 - loss: 0.4691 - val_accuracy: 0.8322 - val_loss: 0.4094
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8102 - loss: 0.4664 - val_accuracy: 0.8182 - val_loss: 0.4080

# %%
Loss, accuracy = model.evaluate(X_test, y_test)

print("test Loss:", Loss)
print("test accuracy:", accuracy)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8178 - loss: 0.4018
# test Loss: 0.41215750575065613
# test accuracy: 0.8100558519363403

# %%
plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
